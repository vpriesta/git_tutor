# %%
set_1 = {'nama' : ["Valen","Nasha","Faiz","Ricky"],
       'kota' : ["Surabaya","Jakarta","Tegal","Semarang"]}

# %%
import pandas as pd

# %%
df_1 = pd.DataFrame(data = set_1)

# %%
df_1
# Out:
#     nama      kota
# 0  Valen  Surabaya
# 1  Nasha   Jakarta
# 2   Faiz     Tegal
# 3  Ricky  Semarang

# %%
df_json = pd.read_json('purchases.json')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_json = pd.read_json('purchases.json')
#
# File D:\DSC_20\Lib\site-packages\pandas\io\json\_json.py:780, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     777 if convert_axes is None and orient != "table":
#     778     convert_axes = True
# --> 780 json_reader = JsonReader(
#     781     path_or_buf,
#     782     orient=orient,
#     783     typ=typ,
#     784     dtype=dtype,
#     785     convert_axes=convert_axes,
#     786     convert_dates=convert_dates,
#     787     keep_default_dates=keep_default_dates,
#     788     precise_float=precise_float,
#     789     date_unit=date_unit,
# ...

# %%
df_json

# %%
df_csv = pd.read_csv('purchases.csv')

# %%
df_csv

# %%
import sqlite3
conn = sqlite3.connect('sqlite3.db')

# %%
df_sql = pd.read_sql_query("SELECT * FROM tweets", conn)

# %%
df_sql
# Out:
#              username                                               text  \
# 0     kembarannyaimas  RT @septian: Sekadar mengingatkan: hasil uji k...
# 1        Rian170363Az  RT @MrsRachelIn: Vaksin corona tiba, Jokowi mi...
# 2            ayu_yude  RT @jokowi: Semenjak dari awal, saya mengingat...
# 3            cak_iwan  RT @septian: Sekadar mengingatkan: hasil uji k...
# 4           vayakikin  RT @AndreasMarbun_: tanggung jawab pemberantas...
# ...               ...                                                ...
# 5634    endanghidayat  RT @CNNIndonesia: Bentrok Polisi-FPI, KAMI Des...
# 5635  Akun_Purwokerto  RT @SOERYAWAD1: Dimohon kpd para buruh dan tem...
# 5636          AA_Gum_  RT @MegaSimarmata: Mundurlah Bapak Kapolda Met...
# 5637  BaksoAc10516490  @detikcom seiring di sahkannya omnibuslaw ini ...
# 5638     indraanurdin                                            Parasit
#
#      retweet_count
# 0                0
# 1                0
# 2                0
# ...

# %%
df_csv['total'] = df_csv['apples'] + df_csv['oranges']

# %%
df_csv_2 = df_csv.copy()
df_csv_2
# Out:
#   Unnamed: 0  apples  oranges  total
# 0       June       3        0      3
# 1     Robert       2        3      5
# 2       Lily       0        7      7
# 3      David       1        2      3

# %%
df_csv_2.to_csv('new_purchases.csv')

# %%
df_movie = pd.read_csv('IMDB-Movie-Data.csv')

# %%
df_movie_2 = df_movie[["Title","Director","Rating"]]
df_movie_2
# Out:
#                        Title              Director  Rating
# 0    Guardians of the Galaxy            James Gunn     8.1
# 1                 Prometheus          Ridley Scott     7.0
# 2                      Split    M. Night Shyamalan     7.3
# 3                       Sing  Christophe Lourdelet     7.2
# 4              Suicide Squad            David Ayer     6.2
# ..                       ...                   ...     ...
# 995     Secret in Their Eyes             Billy Ray     6.2
# 996          Hostel: Part II              Eli Roth     5.5
# 997   Step Up 2: The Streets            Jon M. Chu     6.2
# 998             Search Party        Scot Armstrong     5.6
# 999               Nine Lives      Barry Sonnenfeld     5.3
#
# [1000 rows x 3 columns]

# %%
df_movie_3 = df_movie[df_movie['Runtime (Minutes)'] < 120]
df_movie_3
# Out:
#      Rank                   Title                     Genre  \
# 2       3                   Split           Horror,Thriller
# 3       4                    Sing   Animation,Comedy,Family
# 5       6          The Great Wall  Action,Adventure,Fantasy
# 7       8                Mindhorn                    Comedy
# 9      10              Passengers   Adventure,Drama,Romance
# ..    ...                     ...                       ...
# 995   996    Secret in Their Eyes       Crime,Drama,Mystery
# 996   997         Hostel: Part II                    Horror
# 997   998  Step Up 2: The Streets       Drama,Music,Romance
# 998   999            Search Party          Adventure,Comedy
# 999  1000              Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 2    Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3    In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# ...

# %%
df_movie_4 = df_movie[(df_movie['Runtime (Minutes)'] < 120) & (df_movie['Director'] == 'Christophe Lourdelet')]
df_movie_4
# Out:
#    Rank Title                    Genre  \
# 3     4  Sing  Animation,Comedy,Family
#
#                                          Description              Director  \
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
#
#                                               Actors  Year  Runtime (Minutes)  \
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
#
#    Rating  Votes  Revenue (Millions)  Metascore
# 3     7.2  60545              270.32       59.0

# %%
set_1 = {'nama' : ["Valen","Nasha","Faiz","Ricky","Valen"],
       'kota' : ["Surabaya","Jakarta","Tegal","Semarang","Surabaya"]}

# %%
df_1 = pd.DataFrame(set_1)
df_1
# Out:
#     nama      kota
# 0  Valen  Surabaya
# 1  Nasha   Jakarta
# 2   Faiz     Tegal
# 3  Ricky  Semarang
# 4  Valen  Surabaya

# %%
df_2 = df_1.drop_duplicates()
df_2
# Out:
#     nama      kota
# 0  Valen  Surabaya
# 1  Nasha   Jakarta
# 2   Faiz     Tegal
# 3  Ricky  Semarang

# %%
df_movie.sort_values(by = ['Year','Revenue (Millions)'], ascending = [True,False])
# Out:
#      Rank                                       Title  \
# 78     79  Pirates of the Caribbean: Dead Man's Chest
# 221   222                                        Cars
# 626   627                       X-Men: The Last Stand
# 733   734                           The Da Vinci Code
# 113   114                                         300
# ..    ...                                         ...
# 942   943                                  Transpecos
# 964   965                                     Custody
# 966   967                                   L'odyssée
# 977   978                               Amateur Night
# 978   979              It's Only the End of the World
#
#                           Genre  \
# 78     Action,Adventure,Fantasy
# 221  Animation,Adventure,Comedy
# 626    Action,Adventure,Fantasy
# 733            Mystery,Thriller
# 113          Action,Fantasy,War
# ..                          ...
# 942                    Thriller
# 964                       Drama
# ...

# %%
df_movie.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df_movie_notnull = df_movie.dropna()
df_movie_notnull.shape
# Out:
# (838, 12)

# %%
values = {"Revenue (Millions)" : 82.96, "Metascore" : 58.99}
df_3 = df_movie.fillna(value = values)

# %%
df_movie['Metascore'].mean()
# Out:
# 58.98504273504273

# %%
def rating(x):
    if x > 7.5:
        return "A"
    elif x <=7.5 and x > 6:
        return "B"
    else:
        return "C"

rate = []
for i in df_movie['Rating']:
    r = rating(i)
    rate.append(r)

df_movie['rate'] = rate

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nama    4 non-null      object
#  1   kota    4 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes
